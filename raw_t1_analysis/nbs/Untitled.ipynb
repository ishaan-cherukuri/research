# %%
import pandas as pd

# %%
features_df = pd.read_csv("../features_all_456.csv")

# %%
features_df
# Out:
#      subject_id      mci_bl_datetime  baseline_diagnosis  event_observed  \
# 0    002_S_0729  2006-08-02T00:00:00                 2.0               1
# 1    002_S_0782  2006-08-14T00:00:00                 2.0               0
# 2    002_S_1155  2006-12-14T00:00:00                 2.0               0
# 3    002_S_1268  2007-02-14T00:00:00                 2.0               0
# 4    002_S_2073  2010-09-07T00:00:00                 2.0               0
# ..          ...                  ...                 ...             ...
# 451  153_S_4621  2012-03-28T00:00:00                 2.0               0
# 452  153_S_4838  2012-07-18T00:00:00                 2.0               0
# 453  305_S_6378  2018-05-19T00:00:00                 2.0               0
# 454  941_S_1202  2007-01-30T00:00:00                 2.0               0
# 455  941_S_4764  2012-06-01T00:00:00                 2.0               0
#
#           event_datetime      censor_datetime  event_time_years  aft_y_lower  \
# ...
