# %%
import os
from nilearn import plotting
import pylab as plt
import ants
# %matplotlib inline
base_dir = "/Users/ishu/research/neuro_real/data/raw/oasis3/truenet_oasis3"

file_name = "OAS30001_MR_d2430_anat3_pmap.nii.gz"

full_path = os.path.join(base_dir, file_name)

print(full_path)
# Out:
# /Users/ishu/research/neuro_real/data/raw/oasis3/truenet_oasis3/OAS30001_MR_d2430_anat3_pmap.nii.gz

# %%
import nibabel as nib
import os
import numpy

base_dir = "/Users/ishu/research/neuro_real/data/raw/oasis3/MRI/truenet_oasis3"
file_name = "OAS30001_MR_d2430_anat3_pmap.nii.gz"

path = os.path.join(base_dir, file_name)

img = nib.load(path)
data = img.get_fdata()

print("Shape:", data.shape)
print("Loaded from:", path)
# Out:
# Shape: (256, 256, 35)
# Loaded from: /Users/ishu/research/neuro_real/data/raw/oasis3/MRI/truenet_oasis3/OAS30001_MR_d2430_anat3_pmap.nii.gz

# %%
img.get_fdata().dtype
# Out:
# dtype('float64')

# %%
import numpy as np

# %%
data.shape
# Out:
# (256, 256, 35)

# %%
data = img.get_fdata()
plt.imshow(data[:, :, data.shape[2] // 2].T, cmap='Greys_r')

# %%
img.orthoview()
# Out:
# <div id='7032c155-18be-4518-85a3-67485c4e6307'></div>
# <OrthoSlicer3D: /Users/ishu/research/neuro_real/data/raw/oasis3/MRI/truenet_oasis3/OAS30001_MR_d2430_anat3_pmap.nii.gz (256, 256, 35)>

# %%
affine = img.affine

# %%
list(affine)
# Out:
# [array([-8.59375000e-01,  1.76260742e-10, -0.00000000e+00,  1.10000000e+02]),
#  array([ 1.76260742e-10,  8.59375000e-01,  0.00000000e+00, -8.49517670e+01]),
#  array([  0.       ,   0.       ,   5.       , -94.8062973]),
#  array([0., 0., 0., 1.])]

# %%
x, y, z, _ = np.linalg.pinv(affine).dot(np.array([0, 0, 0, 1])).astype(int)

# %%
z
# Out:
# np.int64(18)
