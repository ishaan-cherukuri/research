# %%
import pandas as pd

# %%
df = pd.read_csv("s3://ishaan-research/data/manifests/adni_manifest_test.csv")

# %%
df
# Out:
#         subject session visit_code    acq_date  \
# 0    002_S_0413      bl         bl  2006-05-19
# 1    002_S_0413      bl         bl  2006-05-19
# 2    002_S_0413     m06        m06  2006-11-15
# 3    002_S_0413     m12        m12  2007-06-01
# 4    002_S_0413     m24        m24  2008-07-31
# ..          ...     ...        ...         ...
# 346  136_S_0429     m06        m06  2006-12-18
# 347  136_S_0429     m12        m12  2007-06-18
# 348  136_S_0429     m18        m18  2007-12-17
# 349  136_S_0429     m24        m24  2008-06-17
# 350  136_S_0429     m36        m36  2009-07-13
#
#                                                   path modality  \
# 0    s3://ishaan-research/data/raw/adni/adni_3yr_3t...      T1w
# 1    s3://ishaan-research/data/raw/adni/adni_3yr_3t...      T1w
# 2    s3://ishaan-research/data/raw/adni/adni_3yr_3t...      T1w
# 3    s3://ishaan-research/data/raw/adni/adni_3yr_3t...      T1w
# 4    s3://ishaan-research/data/raw/adni/adni_3yr_3t...      T1w
# ...

# %%
df[df["image_id"] == "I83389"]
# Out:
#        subject session visit_code    acq_date  \
# 82  023_S_0031     m24        m24  2007-11-14
#
#                                                  path modality  \
# 82  s3://ishaan-research/data/raw/adni/adni_3yr_3t...      T1w
#
#                                         desc image_id diagnosis sex  age
# 82  MPR; GradWarp; B1 Correction; N3; Scaled   I83389        CN   F   80
